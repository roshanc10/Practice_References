# %% [markdown]
# <a href="https://colab.research.google.com/github/roshanc10/Practice_References/blob/main/modelbuilding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data=pd.read_csv('/content/sample_data/Iris.csv')
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data=data.drop('Id',axis=1)

# %%
#Splitting the dependent and independent variables

X=data.iloc[:,:-1]
Y=data['Species']
print("Shape of X is ",X.shape)
print("Shape of Y is ",Y.shape)
# Out:
# Shape of X is  (150, 4)
# Shape of Y is  (150,)

# %%
print(X)
print(Y)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# ...

# %%
#Splitting the train and test dataset

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0 )
print('Shape of X_train is ', X_train.shape)
print('Shape of X_test is ', X_test.shape)
print('Shape of Y_train is ', Y_train.shape)
print('Shape of Y_test is ', Y_test.shape)
# Out:
# Shape of X_train is  (120, 4)
# Shape of X_test is  (30, 4)
# Shape of Y_train is  (120,)
# Shape of Y_test is  (30,)

# %%
#Separating the validation set from train dataset

from sklearn.model_selection import train_test_split

X_train, X_valid, Y_train, Y_valid = train_test_split(X_train, Y_train, test_size=0.2, random_state=0 )
print('Shape of X_train is ', X_train.shape)
print('Shape of X_valid is ', X_valid.shape)
print('Shape of Y_train is ', Y_train.shape)
print('Shape of Y_valid is ', Y_valid.shape)
# Out:
# Shape of X_train is  (96, 4)
# Shape of X_valid is  (24, 4)
# Shape of Y_train is  (96,)
# Shape of Y_valid is  (24,)

# %% [markdown]
# **Standardization**
# Data Standardization is the process of rescaling one or more attributes so that they have a mean value of 0 and a standard deviation of 1.

# %%
#Standardization
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

X_train_sc
# Out:
# array([[-3.23917247e-01, -6.35311704e-02,  1.72396753e-01,
#          1.04190470e-01],
#        [-1.03604066e+00,  1.06591186e+00, -1.24456286e+00,
#         -8.05108177e-01],
#        [ 1.21901681e+00,  3.88246042e-01,  1.07925091e+00,
#          1.40318854e+00],
#        [-1.39210237e+00,  3.88246042e-01, -1.24456286e+00,
#         -1.32470740e+00],
#        [-1.15472789e+00, -1.19297420e+00,  3.99110291e-01,
#          6.23789697e-01],
#        [ 1.57507852e+00, -6.35311704e-02,  1.13592929e+00,
#          4.93889890e-01],
#        [-2.05230011e-01, -2.89419776e-01,  2.29075138e-01,
#          1.04190470e-01],
#        [-4.42604482e-01,  1.06591186e+00, -1.41459802e+00,
#         -1.32470740e+00],
#        [-8.65427759e-02, -7.41196988e-01,  7.39180599e-01,
#          8.83589311e-01],
#        [-1.62947684e+00, -1.64475141e+00, -1.41459802e+00,
#         -1.19480760e+00],
#        [ 2.69518931e-01, -6.35311704e-02,  6.25823830e-01,
#          7.53689504e-01],
# ...

# %% [markdown]
# **Normalization**
# Normalization is a technique applied to change the values of numeric columns in the dataset to use a common scale, without distorting differences in the ranges of values or losing information. Normalization scales down the values in the range from 0 to 1

# %%
from sklearn.preprocessing import MinMaxScaler

mms=MinMaxScaler()
X_train_mms = mms.fit_transform(X_train)
X_test_mms = mms.transform(X_test)

X_train_mms
# Out:
# array([[0.36111111, 0.47619048, 0.51724138, 0.5       ],
#        [0.19444444, 0.71428571, 0.0862069 , 0.20833333],
#        [0.72222222, 0.57142857, 0.79310345, 0.91666667],
#        [0.11111111, 0.57142857, 0.0862069 , 0.04166667],
#        [0.16666667, 0.23809524, 0.5862069 , 0.66666667],
#        [0.80555556, 0.47619048, 0.81034483, 0.625     ],
#        [0.38888889, 0.42857143, 0.53448276, 0.5       ],
#        [0.33333333, 0.71428571, 0.03448276, 0.04166667],
#        [0.41666667, 0.33333333, 0.68965517, 0.75      ],
#        [0.05555556, 0.14285714, 0.03448276, 0.08333333],
#        [0.5       , 0.47619048, 0.65517241, 0.70833333],
#        [0.55555556, 0.66666667, 0.77586207, 0.95833333],
#        [0.38888889, 0.85714286, 0.10344828, 0.08333333],
#        [0.22222222, 0.71428571, 0.05172414, 0.04166667],
#        [0.58333333, 0.57142857, 0.72413793, 0.91666667],
#        [0.94444444, 0.38095238, 0.96551724, 0.79166667],
# ...
